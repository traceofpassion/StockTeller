# %%
import pandas as pd
from tqdm import tqdm
import FinanceDataReader as fdr
from functools import reduce
tqdm.pandas()
info = pd.read_csv('../data/info/stock_info.csv')
kospi = info[info['Market'] == 'KOSPI']['Symbol']

# %%
def PriceCrawling(stock_code):
    temp = fdr.krx.data.KrxDelistingReader(symbol=stock_code, start='2018-01-01', end='2020-12-01').read()
    temp['Symbol'] = stock_code
    temp = temp.reset_index()
    output = temp[['Symbol', 'Date', 'Close', 'Open', 'High', 'Low', 'Volume']]
    return output

# %%
stacked = kospi.progress_apply(lambda x: PriceCrawling(x))
output = reduce(lambda x, y: pd.concat([x, y], axis=0), stacked)
output.to_csv('../data/price/stock_price_kospi.csv', index=False)
