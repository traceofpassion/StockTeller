# %%
import pandas as pd

# %%
data = pd.read_csv('stock_code_kospi.csv')

# %%
data
# Out:
#      StockName  StockCode              TypeBiz  \
# 0       티와이홀딩스     363280               기타 금융업
# 1     코람코에너지리츠     357120         부동산 임대 및 공급업
# 2     제이알글로벌리츠     348950         부동산 임대 및 공급업
# 3     미래에셋맵스리츠     357250         부동산 임대 및 공급업
# 4    이지스레지던스리츠     350520         부동산 임대 및 공급업
# ..         ...        ...                  ...
# 791     CJ대한통운        120            도로 화물 운송업
# 792      메리츠화재         60                  보험업
# 793         경방         50               종합 소매업
# 794      유수홀딩스        700  회사 본부 및 경영 컨설팅 서비스업
# 795   한진중공업홀딩스       3480    연료용 가스 제조 및 배관공급업
#
#                                            MainProduct  OriginDate
# 0                                                 지주사업  2020-09-22
# 1                                          부동산 투자 및 관리  2020-08-31
# 2                                          벨기에 파이낸스 타워  2020-08-07
# 3                                              부동산 임대업  2020-08-05
# ...
